# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("ForestFires.csv")

# %%
#Plotting the data
sns.pairplot(df)

# %%
# df.describe()
# df.info()
df["month"].value_counts()
df["day"].value_counts()
#More fires during the weekend
#More fires in aug / sep
# Out:
# 95

# %%
#Interesting values to look at
#DMC against DC
sns.pairplot()
